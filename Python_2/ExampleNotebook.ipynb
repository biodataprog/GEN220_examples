# %%
print("this is the beginning")
x=-1.0999
if x > 2:
    print("big number")
    print("here")
else:
    print("x is a small number ({})".format(x))
    print("end of the small number message")
print("x ( %d ) times 20 is : _%d_ or %.3f"%(x,
                                             x*20,
                                             x*20))
print("this is after the conditional")
# Out:
# this is the beginning
# x is a small number (-1.0999)
# end of the small number message
# x ( -1 ) times 20 is : _-21_ or -21.998
# this is after the conditional

# %%
numbers = ( 10, -1, 40, 7)
for x in numbers:
    if x < 0:
        x = abs(x)
    print(x)
# Out:
# 10
# 1
# 40
# 7

# %%
x = 0
while x <= 2:
    print("hello ({})".format(x))
    x += 1
# Out:
# hello (0)
# hello (1)
# hello (2)

# %%
for i in range(1,5):
    print(i)
print("")
for i in range(5):
    print(i)
# Out:
# 1
# 2
# 3
# 4
#
# 0
# 1
# 2
# 3
# 4

# %%
print(range(1000000000))
# Out:
# range(0, 1000000000)

# %%
fruit = ("apple", 'pear', "orange", "grape")
print(fruit)
for f in fruit:
    print("fruit is: {}, the string len is {}".format(f,len(f)))
    print("fruit is also:",f)
# Out:
# ('apple', 'pear', 'orange', 'grape')
# fruit is: apple, the string len is 5
# fruit is also: apple
# fruit is: pear, the string len is 4
# fruit is also: pear
# fruit is: orange, the string len is 6
# fruit is also: orange
# fruit is: grape, the string len is 5
# fruit is also: grape

# %%
x=10
if x == 10:
        print("this number 10 == 10 (number)")
if x == "10":
        print("this number 10 == '10' (string)")
x="10"
if x == "10":
        print("this string 10 == '10' (string)")

x="10"
if x is 10:
        print("this string 10 is a 10 (number)")
if x is "10":
        print("This string 10 is a '10' (string)")
# Out:
# this number 10 == 10 (number)
# this string 10 == '10' (string)
# This string 10 is a '10' (string)
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_2109142/233242568.py:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if x is 10:
# /tmp/ipykernel_2109142/233242568.py:13: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if x is "10":

# %%
a = b = [1,2,3]
c = [1,2,3]
print( a == b)   # this is true
print( a == c )  # this is true
print( a is b )  # this is true
print( a is c )  # this is false
# Out:
# True
# True
# True
# False

# %%
headcount=0
tosses = 10000000
for i in range(tosses):
    toss = int(random.random()*2)
    if toss == 1:
        headcount+=1
#    print(toss)
    
print("head count is {} for {} tosses".format(headcount,tosses))
print("freq of heads is %.3f%%"%(headcount/tosses))
# Out:
# head count is 4998597 for 10000000 tosses
# freq of heads is 0.500%

# %%
DNA="AACGCA"
acount = 0
total = 0
for base in DNA:
    print("base is ",base)
    if base == "A":
        acount+=1
    total += 1
print("freq of a is %f"%(acount/total))
# Out:
# base is  A
# base is  A
# base is  C
# base is  G
# base is  C
# base is  A
# freq of a is 0.500000

# %%
mylist = ['a', 'b','c']
mylist.append('z')
mylist[2]='C'
mylist.insert(0,'Start')
print(mylist)
# Out:
# ['Start', 'a', 'b', 'C', 'z']

# %%
mylist = ('a', 'b','c')
# this next line will throw an error
mylist.append('z')

print(mylist)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2109142/1333086880.py in <module>
#       1 mylist = ('a', 'b','c')
#       2 # this next line will throw an error
# ----> 3 mylist.append('z')
#       4
#       5 print(mylist)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
for i in ('a','n'):
    print(i)
    if i is 'n':
        print(i)
# Out:
# a
# a
# n
# n

# %%
DNA="AACGCA"
for base in DNA:
    print("base is ",base)
# Out:
# base is  A
# base is  A
# base is  C
# base is  G
# base is  C
# base is  A

# %%
DNAs = ["AGAGGT","GGTCG",'AACA']
for dnastring in DNAs:
   # print(dnastring)
   # for d1 in dnastring:
       # print("base is ",d1)
    x=15616
    for num in "{}".format(x):
        print("num is ",num)
# Out:
# num is  1
# num is  5
# num is  6
# num is  1
# num is  6
# num is  1
# num is  5
# num is  6
# num is  1
# num is  6
# num is  1
# num is  5
# num is  6
# num is  1
# num is  6

# %%
mylist = ['a', 'b','c']
# this next line will throw an error
mylist.append('z')

print(mylist)
# Out:
# ['a', 'b', 'c', 'z']

# %%
list = ('a', 'b', 'c', 'C','d')
i = 0
for l in list:
#    if l == "b":
#        continue
    i += 1
    if l == "C":
       continue
    print(l)
print(('i is',i,"I hope it makes sense"))
print('i is {}'.format(i))
# Out:
# a
# b
# c
# d
# ('i is', 5, 'I hope it makes sense')
# i is 5

# %%
#!/usr/bin/env python3
ofh = open("my_data.tab","w")
ofh.write("Species\tHabitat\tSize\n")
ofh.write("Crab\tBeach\tM\n")
ofh.write("Fish\tOcean\tS\n")
# Out:
# 13

# %%
import urllib.request
orginfo = "https://raw.githubusercontent.com/biodataprog/GEN220_data/main/data/random_exons.csv"
info = urllib.request.urlopen(orginfo)
for line in info:
    linestrip = line.decode('UTF-8')
    print(linestrip,end="")
# Out:
# Chr7,21408673,21408826
# Chr9,16031526,16031938
# Chr11,4762531,4762595
# Chr8,54040,54193
# Chr10,19815475,19815747
# Chr3,16171331,16172869
# Chr10,2077882,2077938
# Chr3,20517604,20517936
# Chr10,9777446,9777527
# Chr2,4967096,4967246
# Chr4,24437262,24437383
# Chr1,3667439,3668072
# Chr12,86793,86842
# Chr3,15041535,15042398
# Chr2,30051597,30053366
# Chr1,37830781,37831224
# Chr10,18461963,18462253
# Chr1,38895674,38895821
# Chr12,5358668,5358733
# Chr2,10427137,10427293
# Chr2,21453708,21454141
# Chr3,20031693,20031785
# Chr1,18118201,18118438
# Chr3,14716596,14716674
# Chr2,23586057,23586097
# Chr2,33769412,33769509
# Chr1,216884,217664
# Chr11,12744719,12744867
# Chr2,29773339,29773528
# Chr5,29095750,29095816
# Chr4,34894600,34894772
# Chr1,379206,379387
# Chr4,28411207,28411606
# Chr7,27310603,27310739
# Chr7,2082145,2082245
# Chr1,22545361,22545461
# Chr11,27134720,27134863
# Chr6,22863174,22866159
# Chr5,5796532,5797299
# Chr8,15265355,15265478
# Chr3,6573721,6573845
# ...

# %%
example = ['cow','jumps','moon']
print(example)
print(" ".join(example))
mixture = ['ABC',100,1/3]
print(mixture)
#print(";".join(mixture))
convert = map(str,mixture)
print(";".join(convert))
# Out:
# ['cow', 'jumps', 'moon']
# cow jumps moon
# ['ABC', 100, 0.3333333333333333]
# ABC;100;0.3333333333333333

# %%
l = [1,2,3,4]
squares = map(lambda x: x**2,l)
print(l)
print(list(squares))
for i in squares:
    print(i)
# Out:
# [1, 2, 3, 4]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13761/3015662878.py in <module>
#       2 squares = map(lambda x: x**2,l)
#       3 print(l)
# ----> 4 print(list(squares))
#
# TypeError: 'tuple' object is not callable

# %%
genes = ['SOD1','CDC11','YFG1']
print(genes)
sort_genes = sorted(genes)
print("new list",sort_genes)
print("original list",genes)
genes.sort()
print("original list now updated",genes)
# Out:
# ['SOD1', 'CDC11', 'YFG1']
# new list ['CDC11', 'SOD1', 'YFG1']
# original list ['SOD1', 'CDC11', 'YFG1']
# original list now updated ['CDC11', 'SOD1', 'YFG1']

# %%
numbers = [141, 7, 90, 3, 13]
print("unsorted",numbers)
numbers.sort(reverse=True)
print("sorted",numbers)
print("reversed",sorted(numbers,reverse=False))
# Out:
# unsorted [141, 7, 90, 3, 13]
# sorted [141, 90, 13, 7, 3]
# reversed [3, 7, 13, 90, 141]

# %%
print(int('141')/7)
print('141'/7)
# Out:
# 20.142857142857142
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13761/1059246024.py in <module>
#       1 print(int('141')/7)
# ----> 2 print('141'/7)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
alphanumbers = ['141', '7', '90', '3', '13']
print("Alphanumeric strings",alphanumbers)
print("Alpha sorted numbers",sorted(alphanumbers))
print("Numberic sorted",sorted(alphanumbers,key=int))
# Out:
# Alphanumeric strings ['141', '7', '90', '3', '13']
# Alpha sorted numbers ['13', '141', '3', '7', '90']
# Numberic sorted ['3', '7', '13', '90', '141']

# %%
print(int("chr8"[3:]))
print(int("chr10"[3:]))
# Out:
# 8
# 10

# %%
from datetime import datetime

dates = ['3-Jan-2016', '4-Mar-2015', '2-Aug-1999', '1-May-2000']
print(dates)
dates.sort()
print(dates)

#newdates = [ datetime.strptime(d,"%d-%b-%Y") for d in dates ]
newdates = []      
for str in dates:
    newdates.append(datetime.strptime(str,'%d-%b-%Y'))
print(newdates)
newdates.sort()
print(newdates)

for n in newdates:
        print(datetime.strftime(n,"%Y-%b-%d"))
        
#    print(datetime.strftime(n,"%Y-%b-%d")," OR ",
#        datetime.strftime(n,"%Y-%m-%d"), " OR ",
#        datetime.strftime(n,"%A, %b %d, %Y"), " OR ",
#        datetime.strftime(n,"%c")
#        )
# Out:
# ['3-Jan-2016', '4-Mar-2015', '2-Aug-1999', '1-May-2000']
# ['1-May-2000', '2-Aug-1999', '3-Jan-2016', '4-Mar-2015']
# [datetime.datetime(2000, 5, 1, 0, 0), datetime.datetime(1999, 8, 2, 0, 0), datetime.datetime(2016, 1, 3, 0, 0), datetime.datetime(2015, 3, 4, 0, 0)]
# [datetime.datetime(1999, 8, 2, 0, 0), datetime.datetime(2000, 5, 1, 0, 0), datetime.datetime(2015, 3, 4, 0, 0), datetime.datetime(2016, 1, 3, 0, 0)]
# 1999-Aug-02
# 2000-May-01
# 2015-Mar-04
# 2016-Jan-03

# %%
DNA='AAAACCGTAG'
for let in DNA:
    print(let)
print("==")
for let in reversed(DNA):
    print(let)
# Out:
# A
# A
# A
# A
# C
# C
# G
# T
# A
# G
# ==
# G
# A
# T
# G
# C
# C
# A
# A
# A
# A

# %%
import datetime
